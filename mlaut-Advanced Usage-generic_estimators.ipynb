# %%
from download_delgado.delgado_datasets import DownloadAndConvertDelgadoDatasets
from mlaut.data import Data
from mlaut.estimators.estimators import instantiate_default_estimators
from mlaut.experiments import Orchestrator
from mlaut.analyze_results import AnalyseResults
from download_delgado.delgado_datasets import DownloadAndConvertDelgadoDatasets
from mlaut.analyze_results.scores import ScoreAccuracy
import pandas as pd
import numpy as np
from mlaut.estimators.generic_estimator import Generic_Estimator

from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from mlaut.estimators.nn_estimators import Deep_NN_Classifier

# %% [markdown]
# MLAUT is a modelling and workflow toolbox in python, written with the aim of simplifying large scale benchmarking of machine learning strategies, e.g., validation, evaluation and comparison with respect to predictive/task-specific performance or runtime.

# %% [markdown]
# In this example we will demonstrate how the user can define from scratch his own estimator objects and use them for running experiments.
#
# the diagram below sketches the typical MLAUT workflow.

# %% [markdown]
# <img src="img/workflow.png?2">

# %% [markdown]
# ### Step 1: Download the datasets

# %% [markdown]
# For the puposes of this demonstration we will use datasets that can be downloaded from:
# https://persoal.citius.usc.es/manuel.fernandez.delgado/papers/jmlr/data.tar.gz
#
# The datasets were used in the study <cite data-cite="delgado2014">Do we Need Hundreds of Classifiers to solve Real World Classification Problems? (Delgado, 2014)</cite> and were originally downloaded from the UCI Machine Learning Repository.
#
# The code below uses this data and creates two arrays. The first one contains the actual datasets and the scond one the metadata associated with each dataset. The metadata should be in the form of a dictionary and must contain at a minimum
#
# ```python
# {'class_name': ..., #name of the column containing the labels
#  'dataset_name': ... #name of the dataset
# }
# ```
#
# This step is not MLAUT specific but the data needs to be stored in a MLAUT compatible format so that the experiments can be run.
#
# In this example we assume that all datasets can fit into memory and be saved with one command in the database. If this is not the case the user break this process on a dataset by dataset basis or make it even more granular. This step is not MLAUT-specific so it is not discussed in detail in this demo.
#
# The code for downloading the collection of datasets is also not MLAUT-specific and will not be discussed in detail.

# %%
delgado = DownloadAndConvertDelgadoDatasets()
datasets, metadata = delgado.download_and_extract_datasets(verbose = False)
# Out:
# Error: Dataset Delgado_data/molec-biol-protein-second has a different number of arff files

# %% [markdown]
# `datasets`: array of pandas dataframe containing all datasets<br>
# `metadata`: array of dictionaries containing the metadata for each dataset. <br>
#
# The (`dataset`, `metadata`) tuples need to be ordered.

# %% [markdown]
# ### Step 2: Store the datasets in MLAUT format

# %% [markdown]
# The next step is to store the datasets in a format that can be used in MLAUT.
#
# Interaction with MLAUT's data structures is done though the `Data()` class that serves as interface for storing and loading data into HDF5 database which is used by MLAUT for data maniputlation.

# %%
data = Data()
input_io = data.open_hdf5('data/delgado.hdf5', mode='a')
out_io = data.open_hdf5('data/classification.hdf5', mode='a')

# %% [markdown]
# We are now ready to store the data in the HDF5 database.
#
# `save_loc_hdf5` indicates the HDF5 group in which the datasets will be saved.<br>
# `datasets` are the actual datasets in pandas format.<br>
# `dts_metadata` is the metadata array attached to each dataset.<br>
# `input_io` is the class object that interfaces the HDF5 file.

# %%
data.pandas_to_db(save_loc_hdf5='delgado_datasets/', datasets=datasets, 
                  dts_metadata=metadata, input_io=input_io)

# %% [markdown]
# ### Step 3: Split datasets

# %% [markdown]
# The next step is to split the data in test and training.
#
# Unless otherwise specified we use $\dfrac{2}{3}$ of the data for training and $\dfrac{1}{3}$ for testing. We do not change or move the original data in this process. Instead we store the train/test indices in a separate HDF5 database.

# %%
dts_names_list, dts_names_list_full_path = data.list_datasets(hdf5_io=input_io, hdf5_group='delgado_datasets/')
split_dts_list = data.split_datasets(hdf5_in=input_io, hdf5_out=out_io, dataset_paths=dts_names_list_full_path, verbose=False)

# %% [markdown]
# `dts_names_list`: names of the datasets saved inside the HDF5 file <br>
# `dts_names_list_full_path`: full path to the datasets inside the HDF5 database <br>
# `split_dts_list`: path to the train/test indices of the split datasets

# %% [markdown]
# ### Step 4: Define the estimators

# %% [markdown]
# In this advanced use case example we will show how the user can create its own estimator objects

# %%
prop = {'estimator_family':['SVM'], 
            'tasks':['Classification'], 
            'name':'SVC'}

hyperparametes = {
    
                    'C': np.linspace(2**(-5), 2**(15), 13),
                    'gamma': np.linspace(2**(-15), 2**3, 13)
                        
}
est = GridSearchCV(
    SVC(), 
    hyperparametes, 
    verbose = True ,
    n_jobs=-1)

SVC = Generic_Estimator(
    properties_dict = prop, 
            
            estimator=est)

# %%
prop = {'estimator_family':['ENSEMBLE_METHODS'], 
            'tasks':['CLASSIFICATION'], 
            'name':'RandomForestClassifier'}
hyperparameters = {
                'n_estimators': [10, 50, 100],
                'max_features': ['auto', 'sqrt','log2', None],
                'max_depth': [5, 15, None]
                }
estimator = GridSearchCV(RandomForestClassifier(), 
                    hyperparameters, 
                    verbose =  True,
                    n_jobs= -1)
RF = Generic_Estimator(
    properties_dict = prop, 
            estimator=est)

# %%
hyperparameters = {'epochs': [50,100], 
                    'batch_size': 0,  
                    'learning_rate':0.001,
                    'loss': 'mean_squared_error',
                    'optimizer': 'Adam',
                    'metrics' : ['accuracy']}
def keras_model(num_classes, input_dim):
    nn_deep_model = OverwrittenSequentialClassifier()
    nn_deep_model.add(Dense(288, input_dim=input_dim, activation='relu'))
    nn_deep_model.add(Dense(144, activation='relu'))
    nn_deep_model.add(Dropout(0.5))
    nn_deep_model.add(Dense(12, activation='relu'))
    nn_deep_model.add(Dense(num_classes, activation='softmax'))
    return nn_deep_model

deep_nn = Deep_NN_Classifier(hyperparameters=hyperparameters,
                            keras_model=keras_model)

# %% [markdown]
# Please note the different approach to defining custom estimators.
#
# The user can either start with a blank canvas and construct an estimator object from a `Generic_Estimator` class or use an MLAUT estimator (`Deep_NN_Classifier` in this example) and customize it.

# %%
estimators = [SVC, RF, deep_nn]

# %% [markdown]
# ### Step 5: Run the experiments

# %% [markdown]
# At this step we need to select the estimators that we want to use in the study. In this example we enumerated the estimators by name. However, MLAUT also supports a search by task or estimator familily.
#
# The user also needs to instantiate the test orchestrator object by providing reference to the input and output database files and the location of the datasets inside the HDF5 database.
#
# The final step is to run the experiments by invoking the `run()` method.
#
# This step could take a substantial amount of time depending on the number and size of datasets and the number of estimators that we wish to train.

# %%
orchest = Orchestrator(hdf5_input_io=input_io, hdf5_output_io=out_io, dts_names=dts_names_list,
                 original_datasets_group_h5_path='delgado_datasets/')
orchest.run(modelling_strategies=estimators, verbose=False)

# %% [markdown]
# ### Step 6: Make predictions on the test sets

# %% [markdown]
# After the estimators are trained the user needs to use them in order to make predictions on the test sets which will be used subsequently for performing statistical tests.

# %%
orchest.predict_all(trained_models_dir='data/trained_models', estimators=estimators, verbose=False)

# %% [markdown]
# ### Step 7: Analyze the results

# %% [markdown]
# The last step in the pipeline is to analyze the results of the experiments.
#
# The `AnalyseResults` class takes as inputs the two database files and the loss metric that will be used to compute the prediction errors.
#
# The `prediction_errors()` method retuns two sets of results: `errors_per_estimator` dictionary which is used subsequently in further statistical tests and `errors_per_dataset_per_estimator_df` which is a dataframe with the loss of each estimator on each dataset which can be examined directly by the user.

# %%
analyze = AnalyseResults(hdf5_output_io=out_io, 
                         hdf5_input_io=input_io,
                         input_h5_original_datasets_group='delgado_datasets/', 
                         output_h5_predictions_group='experiments/predictions/')
score_accuracy = ScoreAccuracy()


(errors_per_estimator, 
 errors_per_dataset_per_estimator, 
 errors_per_dataset_per_estimator_df) = analyze.prediction_errors(score_accuracy, estimators)

# %% [markdown]
# Below we show the results of the various statistical tests that are supported by MLAUT

# %% [markdown]
# #### t-test

# %%
t_test, t_test_df = analyze.t_test(errors_per_estimator)
t_test_df
# Out:
#                             NeuralNetworkDeepClassifier        \
#                                                  t_stat p_val
# NeuralNetworkDeepClassifier                       0.000   1.0
# RandomForestClassifier                            6.990   0.0
# SVC                                               6.215   0.0
#
#                             RandomForestClassifier           SVC
#                                             t_stat  p_val t_stat  p_val
# NeuralNetworkDeepClassifier                  -6.99  0.000 -6.215  0.000
# RandomForestClassifier                        0.00  1.000  0.940  0.348
# SVC                                          -0.94  0.348  0.000  1.000

# %% [markdown]
# #### sign test

# %%
sign_test, sign_test_df = analyze.sign_test(errors_per_estimator)
sign_test_df
# Out:
#                             NeuralNetworkDeepClassifier        \
#                                                  t_stat p_val
# NeuralNetworkDeepClassifier                       0.000   1.0
# RandomForestClassifier                            6.444   0.0
# SVC                                               5.684   0.0
#
#                             RandomForestClassifier          SVC
#                                             t_stat p_val t_stat p_val
# NeuralNetworkDeepClassifier                 -6.444  0.00 -5.684  0.00
# RandomForestClassifier                       0.000  1.00  1.016  0.31
# SVC                                         -1.016  0.31  0.000  1.00

# %% [markdown]
# #### t-test with bonferroni correction

# %%
t_test_bonferroni_df = analyze.t_test_with_bonferroni_correction(errors_per_estimator)
t_test_bonferroni_df
# Out:
#                              NeuralNetworkDeepClassifier  \
# NeuralNetworkDeepClassifier                        False
# RandomForestClassifier                              True
# SVC                                                 True
#
#                              RandomForestClassifier    SVC
# NeuralNetworkDeepClassifier                    True   True
# RandomForestClassifier                        False  False
# SVC                                           False  False

# %% [markdown]
# #### Wilcoxon test

# %%
import warnings
warnings.filterwarnings('ignore')
wilcoxon_test, wilcoxon_test_df = analyze.wilcoxon_test(errors_per_estimator)
wilcoxon_test_df
# Out:
#                             NeuralNetworkDeepClassifier        \
#                                               statistic p_val
# NeuralNetworkDeepClassifier                         0.0   NaN
# RandomForestClassifier                            269.0   0.0
# SVC                                               263.0   0.0
#
#                             RandomForestClassifier              SVC
#                                          statistic  p_val statistic  p_val
# NeuralNetworkDeepClassifier                  269.0  0.000     263.0  0.000
# RandomForestClassifier                         0.0    NaN    1877.5  0.002
# SVC                                         1877.5  0.002       0.0    NaN

# %% [markdown]
# #### Friedman test

# %%
friedman_test, friedman_test_df = analyze.friedman_test(errors_per_estimator)
friedman_test_df
# Out:
#    statistic  p_value
# 0    110.991      0.0

# %% [markdown]
# #### Nemenyi test

# %%
nemeniy_test = analyze.nemenyi(errors_per_estimator)
nemeniy_test
# Out:
#                              NeuralNetworkDeepClassifier  \
# NeuralNetworkDeepClassifier                         -1.0
# RandomForestClassifier                               0.0
# SVC                                                  0.0
#
#                              RandomForestClassifier    SVC
# NeuralNetworkDeepClassifier                   0.000  0.000
# RandomForestClassifier                       -1.000  0.648
# SVC                                           0.648 -1.000

# %%
nemeniy_test = analyze.nemenyi(errors_per_estimator)
nemeniy_test
# Out:
#                              NeuralNetworkDeepClassifier  \
# NeuralNetworkDeepClassifier                         -1.0
# RandomForestClassifier                               0.0
# SVC                                                  0.0
#
#                              RandomForestClassifier    SVC
# NeuralNetworkDeepClassifier                   0.000  0.000
# RandomForestClassifier                       -1.000  0.648
# SVC                                           0.648 -1.000

# %%
pd.set_option('display.max_rows', 5000)
errors_per_dataset_per_estimator_df
# Out:
#                                                                loss  std_error
# abalone                        NeuralNetworkDeepClassifier  0.37273    0.01302
#                                RandomForestClassifier       0.36476    0.01296
#                                SVC                          0.36186    0.01294
# acute_inflammation             NeuralNetworkDeepClassifier  0.17500    0.06008
#                                RandomForestClassifier       0.00000    0.00000
#                                SVC                          0.00000    0.00000
# acute_nephritis                NeuralNetworkDeepClassifier  0.00000    0.00000
#                                RandomForestClassifier       0.00000    0.00000
#                                SVC                          0.00000    0.00000
# adult                          NeuralNetworkDeepClassifier  0.15380    0.00284
#                                RandomForestClassifier       0.13780    0.00271
#                                SVC                          0.15275    0.00283
# annealing                      NeuralNetworkDeepClassifier  0.24579    0.02498
#                                RandomForestClassifier       0.04377    0.01187
#                                SVC                          0.11111    0.01824
# arrhythmia                     NeuralNetworkDeepClassifier  0.90000    0.02449
#                                RandomForestClassifier       0.25333    0.03551
#                                SVC                          0.28667    0.03692
# audiology_std                  NeuralNetworkDeepClassifier  0.81538    0.04812
#                                RandomForestClassifier       0.06154    0.02981
#                                SVC                          0.04615    0.02602
# balance_scale                  NeuralNetworkDeepClassifier  0.15459    0.02513
#                                RandomForestClassifier       0.14010    0.02412
#                                SVC                          0.07729    0.01856
# balloons                       NeuralNetworkDeepClassifier  0.66667    0.19245
#                                RandomForestClassifier       0.16667    0.15215
#                                SVC                          0.33333    0.19245
# bank                           NeuralNetworkDeepClassifier  0.11327    0.00820
#                                RandomForestClassifier       0.11126    0.00814
#                                SVC                          0.12399    0.00853
# blood                          NeuralNetworkDeepClassifier  0.25506    0.02774
#                                RandomForestClassifier       0.22672    0.02664
#                                SVC                          0.25506    0.02774
# breast_cancer                  NeuralNetworkDeepClassifier  0.29474    0.04678
#                                RandomForestClassifier       0.24211    0.04395
#                                SVC                          0.30526    0.04725
# breast_cancer_wisc             NeuralNetworkDeepClassifier  0.03030    0.01128
#                                RandomForestClassifier       0.03463    0.01203
#                                SVC                          0.03463    0.01203
# breast_cancer_wisc_diag        NeuralNetworkDeepClassifier  0.05851    0.01712
#                                RandomForestClassifier       0.06383    0.01783
#                                SVC                          0.04787    0.01557
# breast_cancer_wisc_prog        NeuralNetworkDeepClassifier  0.28788    0.05573
#                                RandomForestClassifier       0.25758    0.05383
#                                SVC                          0.22727    0.05158
# breast_tissue                  NeuralNetworkDeepClassifier  0.71429    0.07636
#                                RandomForestClassifier       0.28571    0.07636
#                                SVC                          0.34286    0.08023
# car                            NeuralNetworkDeepClassifier  0.18039    0.01609
#                                RandomForestClassifier       0.03152    0.00731
#                                SVC                          0.02452    0.00647
# cardiotocography_10clases      NeuralNetworkDeepClassifier  0.32906    0.01773
#                                RandomForestClassifier       0.13675    0.01297
#                                SVC                          0.17949    0.01448
# cardiotocography_3clases       NeuralNetworkDeepClassifier  0.13675    0.01297
#                                RandomForestClassifier       0.05698    0.00875
#                                SVC                          0.10399    0.01152
# chess_krvk                     NeuralNetworkDeepClassifier  0.59672    0.00510
#                                RandomForestClassifier       0.15131    0.00372
#                                SVC                          0.19300    0.00410
# chess_krvkp                    NeuralNetworkDeepClassifier  0.04645    0.00648
#                                RandomForestClassifier       0.00664    0.00250
#                                SVC                          0.03507    0.00566
# congressional_voting           NeuralNetworkDeepClassifier  0.34028    0.03948
#                                RandomForestClassifier       0.34722    0.03967
#                                SVC                          0.34028    0.03948
# conn_bench_sonar_mines_rocks   NeuralNetworkDeepClassifier  0.42029    0.05942
#                                RandomForestClassifier       0.18841    0.04708
#                                SVC                          0.24638    0.05187
# conn_bench_vowel_deterding     NeuralNetworkDeepClassifier  0.70642    0.02518
#                                RandomForestClassifier       0.01223    0.00608
#                                SVC                          0.00000    0.00000
# connect_4                      NeuralNetworkDeepClassifier  0.21091    0.00273
#                                RandomForestClassifier       0.13214    0.00227
#                                SVC                          0.18880    0.00262
# contrac                        NeuralNetworkDeepClassifier  0.53799    0.02259
#                                RandomForestClassifier       0.40657    0.02226
#                                SVC                          0.48871    0.02265
# credit_approval                NeuralNetworkDeepClassifier  0.12281    0.02174
#                                RandomForestClassifier       0.11842    0.02140
#                                SVC                          0.14035    0.02300
# cylinder_bands                 NeuralNetworkDeepClassifier  0.34320    0.03652
#                                RandomForestClassifier       0.20118    0.03084
#                                SVC                          0.27219    0.03424
# dermatology                    NeuralNetworkDeepClassifier  0.35537    0.04351
#                                RandomForestClassifier       0.03306    0.01625
#                                SVC                          0.02479    0.01414
# echocardiogram                 NeuralNetworkDeepClassifier  0.25000    0.06528
#                                RandomForestClassifier       0.20455    0.06081
#                                SVC                          0.20455    0.06081
# ecoli                          NeuralNetworkDeepClassifier  0.21622    0.03907
#                                RandomForestClassifier       0.16216    0.03499
#                                SVC                          0.11712    0.03052
# energy_y1                      NeuralNetworkDeepClassifier  0.20472    0.02532
#                                RandomForestClassifier       0.02756    0.01027
#                                SVC                          0.06693    0.01568
# energy_y2                      NeuralNetworkDeepClassifier  0.19291    0.02476
#                                RandomForestClassifier       0.08268    0.01728
#                                SVC                          0.08661    0.01765
# fertility                      NeuralNetworkDeepClassifier  0.18182    0.06714
#                                RandomForestClassifier       0.18182    0.06714
#                                SVC                          0.18182    0.06714
# flags                          NeuralNetworkDeepClassifier  0.50769    0.06201
#                                RandomForestClassifier       0.29231    0.05641
#                                SVC                          0.58462    0.06112
# glass                          NeuralNetworkDeepClassifier  0.56338    0.05886
#                                RandomForestClassifier       0.18310    0.04590
#                                SVC                          0.32394    0.05554
# haberman_survival              NeuralNetworkDeepClassifier  0.27723    0.04454
#                                RandomForestClassifier       0.31683    0.04629
#                                SVC                          0.26733    0.04404
# hayes_roth                     NeuralNetworkDeepClassifier  0.52830    0.06857
#                                RandomForestClassifier       0.15094    0.04917
#                                SVC                          0.18868    0.05374
# heart_cleveland                NeuralNetworkDeepClassifier  0.66000    0.04737
#                                RandomForestClassifier       0.40000    0.04899
#                                SVC                          0.35000    0.04770
# heart_hungarian                NeuralNetworkDeepClassifier  0.19388    0.03993
#                                RandomForestClassifier       0.16327    0.03734
#                                SVC                          0.17347    0.03825
# heart_switzerland              NeuralNetworkDeepClassifier  0.73171    0.06920
#                                RandomForestClassifier       0.58537    0.07694
#                                SVC                          0.60976    0.07618
# heart_va                       NeuralNetworkDeepClassifier  0.83333    0.04587
#                                RandomForestClassifier       0.75758    0.05275
#                                SVC                          0.74242    0.05383
# hepatitis                      NeuralNetworkDeepClassifier  0.19231    0.05465
#                                RandomForestClassifier       0.19231    0.05465
#                                SVC                          0.19231    0.05465
# hill_valley                    NeuralNetworkDeepClassifier  0.51500    0.02499
#                                RandomForestClassifier       0.16250    0.01845
#                                SVC                          0.27750    0.02239
# horse_colic                    NeuralNetworkDeepClassifier  0.27049    0.04022
#                                RandomForestClassifier       0.04098    0.01795
#                                SVC                          0.12295    0.02973
# ilpd_indian_liver              NeuralNetworkDeepClassifier  0.29016    0.03267
#                                RandomForestClassifier       0.29534    0.03284
#                                SVC                          0.29016    0.03267
# image_segmentation             NeuralNetworkDeepClassifier  0.68938    0.01675
#                                RandomForestClassifier       0.03408    0.00657
#                                SVC                          0.03539    0.00669
# ionosphere                     NeuralNetworkDeepClassifier  0.11207    0.02929
#                                RandomForestClassifier       0.10345    0.02828
#                                SVC                          0.13793    0.03202
# iris                           NeuralNetworkDeepClassifier  0.48000    0.07065
#                                RandomForestClassifier       0.04000    0.02771
#                                SVC                          0.02000    0.01980
# led_display                    NeuralNetworkDeepClassifier  0.49394    0.02752
#                                RandomForestClassifier       0.29697    0.02515
#                                SVC                          0.27879    0.02468
# lenses                         NeuralNetworkDeepClassifier  0.50000    0.17678
#                                RandomForestClassifier       0.12500    0.11693
#                                SVC                          0.12500    0.11693
# letter                         NeuralNetworkDeepClassifier  0.34561    0.00585
#                                RandomForestClassifier       0.04485    0.00255
#                                SVC                          0.04591    0.00258
# libras                         NeuralNetworkDeepClassifier  0.81513    0.03559
#                                RandomForestClassifier       0.25210    0.03980
#                                SVC                          0.23529    0.03888
# low_res_spect                  NeuralNetworkDeepClassifier  0.38636    0.03670
#                                RandomForestClassifier       0.10227    0.02284
#                                SVC                          0.09659    0.02227
# lung_cancer                    NeuralNetworkDeepClassifier  0.54545    0.15013
#                                RandomForestClassifier       0.45455    0.15013
#                                SVC                          0.54545    0.15013
# lymphography                   NeuralNetworkDeepClassifier  0.38776    0.06961
#                                RandomForestClassifier       0.20408    0.05758
#                                SVC                          0.20408    0.05758
# magic                          NeuralNetworkDeepClassifier  0.15151    0.00453
#                                RandomForestClassifier       0.12410    0.00416
#                                SVC                          0.17365    0.00478
# mammographic                   NeuralNetworkDeepClassifier  0.20755    0.02274
#                                RandomForestClassifier       0.12893    0.01879
#                                SVC                          0.18239    0.02166
# miniboone                      NeuralNetworkDeepClassifier  0.09075    0.00139
#                                RandomForestClassifier       0.06353    0.00118
#                                SVC                          0.09140    0.00139
# molec_biol_promoter            NeuralNetworkDeepClassifier  0.62857    0.08167
#                                RandomForestClassifier       0.17143    0.06370
#                                SVC                          0.20000    0.06761
# molec_biol_splice              NeuralNetworkDeepClassifier  0.23932    0.01315
#                                RandomForestClassifier       0.05128    0.00680
#                                SVC                          0.15480    0.01115
# monks_1                        NeuralNetworkDeepClassifier  0.25543    0.03215
#                                RandomForestClassifier       0.00543    0.00542
#                                SVC                          0.03804    0.01410
# monks_2                        NeuralNetworkDeepClassifier  0.34171    0.03362
#                                RandomForestClassifier       0.06030    0.01687
#                                SVC                          0.07035    0.01813
# monks_3                        NeuralNetworkDeepClassifier  0.22951    0.03109
#                                RandomForestClassifier       0.01093    0.00769
#                                SVC                          0.07104    0.01899
# mushroom                       NeuralNetworkDeepClassifier  0.00410    0.00123
#                                RandomForestClassifier       0.00000    0.00000
#                                SVC                          0.00112    0.00065
# musk_1                         NeuralNetworkDeepClassifier  0.22152    0.03304
#                                RandomForestClassifier       0.13924    0.02754
#                                SVC                          0.14557    0.02806
# musk_2                         NeuralNetworkDeepClassifier  0.05234    0.00477
#                                RandomForestClassifier       0.02433    0.00330
#                                SVC                          0.02158    0.00311
# nursery                        NeuralNetworkDeepClassifier  0.07342    0.00399
#                                RandomForestClassifier       0.00304    0.00084
#                                SVC                          0.00257    0.00077
# oocytes_merluccius_nucleus_4d  NeuralNetworkDeepClassifier  0.29882    0.02490
#                                RandomForestClassifier       0.19527    0.02156
#                                SVC                          0.16568    0.02022
# oocytes_merluccius_states_2f   NeuralNetworkDeepClassifier  0.12130    0.01776
#                                RandomForestClassifier       0.07692    0.01449
#                                SVC                          0.08580    0.01523
# oocytes_trisopterus_nucleus_2f NeuralNetworkDeepClassifier  0.32226    0.02694
#                                RandomForestClassifier       0.22591    0.02410
#                                SVC                          0.19601    0.02288
# oocytes_trisopterus_states_5b  NeuralNetworkDeepClassifier  0.19269    0.02273
#                                RandomForestClassifier       0.08638    0.01619
#                                SVC                          0.07973    0.01561
# optical                        NeuralNetworkDeepClassifier  0.05445    0.00527
#                                RandomForestClassifier       0.00701    0.00194
#                                SVC                          0.00863    0.00215
# ozone                          NeuralNetworkDeepClassifier  0.02987    0.00588
#                                RandomForestClassifier       0.02987    0.00588
#                                SVC                          0.02987    0.00588
# page_blocks                    NeuralNetworkDeepClassifier  0.07084    0.00604
#                                RandomForestClassifier       0.02933    0.00397
#                                SVC                          0.03818    0.00451
# parkinsons                     NeuralNetworkDeepClassifier  0.30769    0.05725
#                                RandomForestClassifier       0.16923    0.04651
#                                SVC                          0.15385    0.04475
# pendigits                      NeuralNetworkDeepClassifier  0.05733    0.00386
#                                RandomForestClassifier       0.00413    0.00107
#                                SVC                          0.00469    0.00113
# pima                           NeuralNetworkDeepClassifier  0.24803    0.02710
#                                RandomForestClassifier       0.20472    0.02532
#                                SVC                          0.21654    0.02584
# pittsburg_bridges_MATERIAL     NeuralNetworkDeepClassifier  0.17143    0.06370
#                                RandomForestClassifier       0.14286    0.05915
#                                SVC                          0.14286    0.05915
# pittsburg_bridges_REL_L        NeuralNetworkDeepClassifier  0.35294    0.08196
#                                RandomForestClassifier       0.41176    0.08440
#                                SVC                          0.44118    0.08515
# pittsburg_bridges_SPAN         NeuralNetworkDeepClassifier  0.48387    0.08976
#                                RandomForestClassifier       0.19355    0.07096
#                                SVC                          0.32258    0.08396
# pittsburg_bridges_TYPE         NeuralNetworkDeepClassifier  0.65714    0.08023
#                                RandomForestClassifier       0.40000    0.08281
#                                SVC                          0.40000    0.08281
# pittsburg_bridges_T_OR_D       NeuralNetworkDeepClassifier  0.20588    0.06934
#                                RandomForestClassifier       0.26471    0.07566
#                                SVC                          0.23529    0.07275
# planning                       NeuralNetworkDeepClassifier  0.27869    0.05741
#                                RandomForestClassifier       0.34426    0.06083
#                                SVC                          0.27869    0.05741
# plant_margin                   NeuralNetworkDeepClassifier  0.97159    0.00723
#                                RandomForestClassifier       0.20455    0.01755
#                                SVC                          0.19318    0.01718
# plant_shape                    NeuralNetworkDeepClassifier  0.97727    0.00649
#                                RandomForestClassifier       0.41098    0.02141
#                                SVC                          0.32008    0.02030
# plant_texture                  NeuralNetworkDeepClassifier  0.96212    0.00831
#                                RandomForestClassifier       0.17992    0.01672
#                                SVC                          0.17992    0.01672
# post_operative                 NeuralNetworkDeepClassifier  0.23333    0.07722
#                                RandomForestClassifier       0.33333    0.08607
#                                SVC                          0.26667    0.08074
# primary_tumor                  NeuralNetworkDeepClassifier  0.71560    0.04321
#                                RandomForestClassifier       0.55046    0.04765
#                                SVC                          0.56881    0.04744
# ringnorm                       NeuralNetworkDeepClassifier  0.06839    0.00511
#                                RandomForestClassifier       0.03767    0.00385
#                                SVC                          0.01925    0.00278
# seeds                          NeuralNetworkDeepClassifier  0.24286    0.05125
#                                RandomForestClassifier       0.04286    0.02421
#                                SVC                          0.05714    0.02774
# semeion                        NeuralNetworkDeepClassifier  0.45817    0.02172
#                                RandomForestClassifier       0.07414    0.01142
#                                SVC                          0.06084    0.01042
# soybean                        NeuralNetworkDeepClassifier  0.55310    0.03307
#                                RandomForestClassifier       0.02655    0.01069
#                                SVC                          0.04425    0.01368
# spambase                       NeuralNetworkDeepClassifier  0.06715    0.00642
#                                RandomForestClassifier       0.04411    0.00527
#                                SVC                          0.06649    0.00639
# spect                          NeuralNetworkDeepClassifier  0.43182    0.05280
#                                RandomForestClassifier       0.36364    0.05128
#                                SVC                          0.31818    0.04965
# spectf                         NeuralNetworkDeepClassifier  0.17978    0.04070
#                                RandomForestClassifier       0.07865    0.02853
#                                SVC                          0.05618    0.02441
# statlog_australian_credit      NeuralNetworkDeepClassifier  0.31579    0.03078
#                                RandomForestClassifier       0.31140    0.03067
#                                SVC                          0.31579    0.03078
# statlog_german_credit          NeuralNetworkDeepClassifier  0.27879    0.02468
#                                RandomForestClassifier       0.22424    0.02296
#                                SVC                          0.22424    0.02296
# statlog_heart                  NeuralNetworkDeepClassifier  0.21111    0.04302
#                                RandomForestClassifier       0.20000    0.04216
#                                SVC                          0.22222    0.04382
# statlog_image                  NeuralNetworkDeepClassifier  0.17300    0.01369
#                                RandomForestClassifier       0.01966    0.00503
#                                SVC                          0.05242    0.00807
# statlog_landsat                NeuralNetworkDeepClassifier  0.14266    0.00759
#                                RandomForestClassifier       0.09934    0.00649
#                                SVC                          0.10405    0.00662
# statlog_shuttle                NeuralNetworkDeepClassifier  0.00428    0.00047
#                                RandomForestClassifier       0.00010    0.00007
#                                SVC                          0.00037    0.00014
# statlog_vehicle                NeuralNetworkDeepClassifier  0.43571    0.02963
#                                RandomForestClassifier       0.26429    0.02635
#                                SVC                          0.17857    0.02289
# steel_plates                   NeuralNetworkDeepClassifier  0.43682    0.01959
#                                RandomForestClassifier       0.23089    0.01664
#                                SVC                          0.25585    0.01723
# synthetic_control              NeuralNetworkDeepClassifier  0.36364    0.03419
#                                RandomForestClassifier       0.00505    0.00504
#                                SVC                          0.01010    0.00711
# teaching                       NeuralNetworkDeepClassifier  0.68000    0.06597
#                                RandomForestClassifier       0.36000    0.06788
#                                SVC                          0.42000    0.06980
# thyroid                        NeuralNetworkDeepClassifier  0.06145    0.00493
#                                RandomForestClassifier       0.00463    0.00139
#                                SVC                          0.03662    0.00385
# tic_tac_toe                    NeuralNetworkDeepClassifier  0.33438    0.02650
#                                RandomForestClassifier       0.03155    0.00982
#                                SVC                          0.02524    0.00881
# titanic                        NeuralNetworkDeepClassifier  0.25585    0.01618
#                                RandomForestClassifier       0.24072    0.01586
#                                SVC                          0.24072    0.01586
# trains                         NeuralNetworkDeepClassifier  0.75000    0.21651
#                                RandomForestClassifier       0.00000    0.00000
#                                SVC                          0.25000    0.21651
# twonorm                        NeuralNetworkDeepClassifier  0.02662    0.00326
#                                RandomForestClassifier       0.03194    0.00356
#                                SVC                          0.02416    0.00311
# vertebral_column_2clases       NeuralNetworkDeepClassifier  0.20388    0.03970
#                                RandomForestClassifier       0.11650    0.03161
#                                SVC                          0.09709    0.02917
# vertebral_column_3clases       NeuralNetworkDeepClassifier  0.30097    0.04520
#                                RandomForestClassifier       0.13592    0.03377
#                                SVC                          0.11650    0.03161
# wall_following                 NeuralNetworkDeepClassifier  0.23598    0.01001
#                                RandomForestClassifier       0.00278    0.00124
#                                SVC                          0.18490    0.00915
# waveform                       NeuralNetworkDeepClassifier  0.13697    0.00846
#                                RandomForestClassifier       0.14606    0.00869
#                                SVC                          0.12727    0.00820
# waveform_noise                 NeuralNetworkDeepClassifier  0.14242    0.00860
#                                RandomForestClassifier       0.14667    0.00871
#                                SVC                          0.14000    0.00854
# wine                           NeuralNetworkDeepClassifier  0.23729    0.05539
#                                RandomForestClassifier       0.01695    0.01680
#                                SVC                          0.05085    0.02860
# wine_quality_red               NeuralNetworkDeepClassifier  0.42803    0.02153
#                                RandomForestClassifier       0.31061    0.02014
#                                SVC                          0.36553    0.02096
# wine_quality_white             NeuralNetworkDeepClassifier  0.48918    0.01243
#                                RandomForestClassifier       0.33952    0.01178
#                                SVC                          0.35498    0.01190
# yeast                          NeuralNetworkDeepClassifier  0.57959    0.02230
#                                RandomForestClassifier       0.40816    0.02220
#                                SVC                          0.44286    0.02244
# zoo                            NeuralNetworkDeepClassifier  0.44118    0.08515
#                                RandomForestClassifier       0.05882    0.04035
#                                SVC                          0.02941    0.02898
