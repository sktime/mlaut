# %%
from mlaut.analyze_results import AnalyseResults
from mlaut.data import Data
from mlaut.data.data import Data
import pickle
import numpy as np
from sklearn.metrics import mean_squared_error
from mlaut.experiments import Orchestrator
from mlaut.data.estimators import instantiate_default_estimators
import os
# Out:
# C:\Python\envs\py36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
data = Data()
input_io = data.open_hdf5('data/delgado.hdf5', mode='r')
out_io = data.open_hdf5('data/classification.hdf5', mode='a')

# %%
dts_names = os.listdir('data/trained_models')
orchest = Orchestrator(hdf5_input_io=input_io, 
                           hdf5_output_io=out_io,
                           dts_names=dts_names,
                           original_datasets_group_h5_path='/delgado_datasets')

# %%
instantiated_models = instantiate_default_estimators(estimators=['NeuralNetworkDeepClassifier'], verbose=1)
orchest.predict_all(trained_models_dir='data/trained_models', estimators=instantiated_models)
# Out:
# Skipping trained estimator LogisticRegression. Saved on disk but not instantiated.
# Skipping trained estimator RidgeRegression. Saved on disk but not instantiated.
# Skipping trained estimator Lasso. Saved on disk but not instantiated.
# Skipping trained estimator LassoLars. Saved on disk but not instantiated.
# Skipping trained estimator RandomForestClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaggingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator GradientBoostingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator SVC. Saved on disk but not instantiated.
# Skipping trained estimator GaussianNaiveBayes. Saved on disk but not instantiated.
# Skipping trained estimator BernoulliNaiveBayes. Saved on disk but not instantiated.
#   32/1379 [..............................] - ETA: 0sPredictions of estimator NeuralNetworkDeepClassifier on abalone stored in database
# Skipping trained estimator PassiveAggressiveClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaselineClassifier. Saved on disk but not instantiated.
# Skipping trained estimator LogisticRegression. Saved on disk but not instantiated.
# Skipping trained estimator RidgeRegression. Saved on disk but not instantiated.
# Skipping trained estimator Lasso. Saved on disk but not instantiated.
# Skipping trained estimator LassoLars. Saved on disk but not instantiated.
# Skipping trained estimator RandomForestClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaggingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator GradientBoostingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator SVC. Saved on disk but not instantiated.
# Skipping trained estimator GaussianNaiveBayes. Saved on disk but not instantiated.
# Skipping trained estimator BernoulliNaiveBayes. Saved on disk but not instantiated.
# 32/40 [=======================>......] - ETA: 0sPredictions of estimator NeuralNetworkDeepClassifier on acute_inflammation stored in database
# Skipping trained estimator PassiveAggressiveClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaselineClassifier. Saved on disk but not instantiated.
# Skipping trained estimator LogisticRegression. Saved on disk but not instantiated.
# Skipping trained estimator RidgeRegression. Saved on disk but not instantiated.
# Skipping trained estimator Lasso. Saved on disk but not instantiated.
# Skipping trained estimator LassoLars. Saved on disk but not instantiated.
# Skipping trained estimator RandomForestClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaggingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator GradientBoostingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator SVC. Saved on disk but not instantiated.
# Skipping trained estimator GaussianNaiveBayes. Saved on disk but not instantiated.
# Skipping trained estimator BernoulliNaiveBayes. Saved on disk but not instantiated.
# 32/40 [=======================>......] - ETA: 0sPredictions of estimator NeuralNetworkDeepClassifier on acute_nephritis stored in database
# Skipping trained estimator PassiveAggressiveClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaselineClassifier. Saved on disk but not instantiated.
# Skipping trained estimator LogisticRegression. Saved on disk but not instantiated.
# Skipping trained estimator RidgeRegression. Saved on disk but not instantiated.
# Skipping trained estimator Lasso. Saved on disk but not instantiated.
# Skipping trained estimator LassoLars. Saved on disk but not instantiated.
# Skipping trained estimator RandomForestClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaggingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator GradientBoostingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator SVC. Saved on disk but not instantiated.
# Skipping trained estimator GaussianNaiveBayes. Saved on disk but not instantiated.
# Skipping trained estimator BernoulliNaiveBayes. Saved on disk but not instantiated.
# 15296/16118 [===========================>..] - ETA: 0sPredictions of estimator NeuralNetworkDeepClassifier on adult stored in database
# Skipping trained estimator PassiveAggressiveClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaselineClassifier. Saved on disk but not instantiated.
# Skipping trained estimator LogisticRegression. Saved on disk but not instantiated.
# Skipping trained estimator RidgeRegression. Saved on disk but not instantiated.
# Skipping trained estimator Lasso. Saved on disk but not instantiated.
# Skipping trained estimator LassoLars. Saved on disk but not instantiated.
# Skipping trained estimator RandomForestClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaggingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator GradientBoostingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator SVC. Saved on disk but not instantiated.
# Skipping trained estimator GaussianNaiveBayes. Saved on disk but not instantiated.
# Skipping trained estimator BernoulliNaiveBayes. Saved on disk but not instantiated.
#  32/297 [==>...........................] - ETA: 0sPredictions of estimator NeuralNetworkDeepClassifier on annealing stored in database
# Skipping trained estimator PassiveAggressiveClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaselineClassifier. Saved on disk but not instantiated.
# Skipping trained estimator LogisticRegression. Saved on disk but not instantiated.
# Skipping trained estimator RidgeRegression. Saved on disk but not instantiated.
# Skipping trained estimator Lasso. Saved on disk but not instantiated.
# Skipping trained estimator LassoLars. Saved on disk but not instantiated.
# Skipping trained estimator RandomForestClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaggingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator GradientBoostingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator SVC. Saved on disk but not instantiated.
# Skipping trained estimator GaussianNaiveBayes. Saved on disk but not instantiated.
# Skipping trained estimator BernoulliNaiveBayes. Saved on disk but not instantiated.
#  32/150 [=====>........................] - ETA: 0sPredictions of estimator NeuralNetworkDeepClassifier on arrhythmia stored in database
# Skipping trained estimator PassiveAggressiveClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaselineClassifier. Saved on disk but not instantiated.
# Skipping trained estimator LogisticRegression. Saved on disk but not instantiated.
# Skipping trained estimator RidgeRegression. Saved on disk but not instantiated.
# Skipping trained estimator Lasso. Saved on disk but not instantiated.
# Skipping trained estimator LassoLars. Saved on disk but not instantiated.
# Skipping trained estimator RandomForestClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaggingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator GradientBoostingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator SVC. Saved on disk but not instantiated.
# Skipping trained estimator GaussianNaiveBayes. Saved on disk but not instantiated.
# Skipping trained estimator BernoulliNaiveBayes. Saved on disk but not instantiated.
# 32/65 [=============>................] - ETA: 0sPredictions of estimator NeuralNetworkDeepClassifier on audiology_std stored in database
# Skipping trained estimator PassiveAggressiveClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaselineClassifier. Saved on disk but not instantiated.
# Skipping trained estimator LogisticRegression. Saved on disk but not instantiated.
# Skipping trained estimator RidgeRegression. Saved on disk but not instantiated.
# Skipping trained estimator Lasso. Saved on disk but not instantiated.
# Skipping trained estimator LassoLars. Saved on disk but not instantiated.
# Skipping trained estimator RandomForestClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaggingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator GradientBoostingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator SVC. Saved on disk but not instantiated.
# Skipping trained estimator GaussianNaiveBayes. Saved on disk but not instantiated.
# Skipping trained estimator BernoulliNaiveBayes. Saved on disk but not instantiated.
#  32/207 [===>..........................] - ETA: 0sPredictions of estimator NeuralNetworkDeepClassifier on balance_scale stored in database
# Skipping trained estimator PassiveAggressiveClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaselineClassifier. Saved on disk but not instantiated.
# Skipping trained estimator LogisticRegression. Saved on disk but not instantiated.
# Skipping trained estimator RidgeRegression. Saved on disk but not instantiated.
# Skipping trained estimator Lasso. Saved on disk but not instantiated.
# Skipping trained estimator LassoLars. Saved on disk but not instantiated.
# Skipping trained estimator RandomForestClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaggingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator GradientBoostingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator SVC. Saved on disk but not instantiated.
# Skipping trained estimator GaussianNaiveBayes. Saved on disk but not instantiated.
# Skipping trained estimator BernoulliNaiveBayes. Saved on disk but not instantiated.
# 6/6 [==============================] - 0s
# Predictions of estimator NeuralNetworkDeepClassifier on balloons stored in database
# Skipping trained estimator PassiveAggressiveClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaselineClassifier. Saved on disk but not instantiated.
# Skipping trained estimator LogisticRegression. Saved on disk but not instantiated.
# Skipping trained estimator RidgeRegression. Saved on disk but not instantiated.
# Skipping trained estimator Lasso. Saved on disk but not instantiated.
# Skipping trained estimator LassoLars. Saved on disk but not instantiated.
# Skipping trained estimator RandomForestClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaggingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator GradientBoostingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator SVC. Saved on disk but not instantiated.
# Skipping trained estimator GaussianNaiveBayes. Saved on disk but not instantiated.
# Skipping trained estimator BernoulliNaiveBayes. Saved on disk but not instantiated.
#   32/1492 [..............................] - ETA: 8sPredictions of estimator NeuralNetworkDeepClassifier on bank stored in database
# Skipping trained estimator PassiveAggressiveClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaselineClassifier. Saved on disk but not instantiated.
# Skipping trained estimator LogisticRegression. Saved on disk but not instantiated.
# Skipping trained estimator RidgeRegression. Saved on disk but not instantiated.
# Skipping trained estimator Lasso. Saved on disk but not instantiated.
# Skipping trained estimator LassoLars. Saved on disk but not instantiated.
# Skipping trained estimator RandomForestClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaggingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator GradientBoostingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator SVC. Saved on disk but not instantiated.
# Skipping trained estimator GaussianNaiveBayes. Saved on disk but not instantiated.
# Skipping trained estimator BernoulliNaiveBayes. Saved on disk but not instantiated.
#  32/247 [==>...........................] - ETA: 1sPredictions of estimator NeuralNetworkDeepClassifier on blood stored in database
# Skipping trained estimator PassiveAggressiveClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaselineClassifier. Saved on disk but not instantiated.
# Skipping trained estimator LogisticRegression. Saved on disk but not instantiated.
# Skipping trained estimator RidgeRegression. Saved on disk but not instantiated.
# Skipping trained estimator Lasso. Saved on disk but not instantiated.
# Skipping trained estimator LassoLars. Saved on disk but not instantiated.
# Skipping trained estimator RandomForestClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaggingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator GradientBoostingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator SVC. Saved on disk but not instantiated.
# Skipping trained estimator GaussianNaiveBayes. Saved on disk but not instantiated.
# Skipping trained estimator BernoulliNaiveBayes. Saved on disk but not instantiated.
# 32/95 [=========>....................] - ETA: 0sPredictions of estimator NeuralNetworkDeepClassifier on breast_cancer stored in database
# Skipping trained estimator PassiveAggressiveClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaselineClassifier. Saved on disk but not instantiated.
# Skipping trained estimator LogisticRegression. Saved on disk but not instantiated.
# Skipping trained estimator RidgeRegression. Saved on disk but not instantiated.
# Skipping trained estimator Lasso. Saved on disk but not instantiated.
# Skipping trained estimator LassoLars. Saved on disk but not instantiated.
# Skipping trained estimator RandomForestClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaggingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator GradientBoostingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator SVC. Saved on disk but not instantiated.
# Skipping trained estimator GaussianNaiveBayes. Saved on disk but not instantiated.
# Skipping trained estimator BernoulliNaiveBayes. Saved on disk but not instantiated.
#  32/231 [===>..........................] - ETA: 1sPredictions of estimator NeuralNetworkDeepClassifier on breast_cancer_wisc stored in database
# Skipping trained estimator PassiveAggressiveClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaselineClassifier. Saved on disk but not instantiated.
# Skipping trained estimator LogisticRegression. Saved on disk but not instantiated.
# Skipping trained estimator RidgeRegression. Saved on disk but not instantiated.
# Skipping trained estimator Lasso. Saved on disk but not instantiated.
# Skipping trained estimator LassoLars. Saved on disk but not instantiated.
# Skipping trained estimator RandomForestClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaggingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator GradientBoostingClassifier. Saved on disk but not instantiated.
# Skipping trained estimator SVC. Saved on disk but not instantiated.
# Skipping trained estimator GaussianNaiveBayes. Saved on disk but not instantiated.
# Skipping trained estimator BernoulliNaiveBayes. Saved on disk but not instantiated.
#  32/188 [====>.........................] - ETA: 1sPredictions of estimator NeuralNetworkDeepClassifier on breast_cancer_wisc_diag stored in database
# Skipping trained estimator PassiveAggressiveClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaselineClassifier. Saved on disk but not instantiated.
# Skipping trained estimator LogisticRegression. Saved on disk but not instantiated.
# Skipping trained estimator RidgeRegression. Saved on disk but not instantiated.
# Skipping trained estimator Lasso. Saved on disk but not instantiated.
# Skipping trained estimator LassoLars. Saved on disk but not instantiated.
# Skipping trained estimator RandomForestClassifier. Saved on disk but not instantiated.
# Skipping trained estimator BaggingClassifier. Saved on disk but not instantiated.

# %%
instantiated_models[0].properties()
# Out:
# {'estimator_family': ['Neural Networks'],
#  'name': 'NeuralNetworkDeepClassifier',
#  'tasks': ['Classification']}
